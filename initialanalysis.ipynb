# %%
import pandas as pd
df = pd.read_csv('flavors_of_cacao1.csv')

# %%
df
# Out:
#                  Company                        SpecificBean   REF  \
# 0               A. Morin                         Agua Grande  1876
# 1               A. Morin                               Kpime  1676
# 2               A. Morin                              Atsane  1676
# 3               A. Morin                               Akata  1680
# 4               A. Morin                              Quilla  1704
# 5               A. Morin                            Carenero  1315
# 6               A. Morin                                Cuba  1315
# 7               A. Morin                        Sur del Lago  1315
# 8               A. Morin                      Puerto Cabello  1319
# 9               A. Morin                             Pablino  1319
# 10              A. Morin                              Panama  1011
# 11              A. Morin                          Madagascar  1011
# 12              A. Morin                              Brazil  1011
# ...

# %%
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline
sns.distplot(df["Rating"])

# %%
sns.regplot(x=df["REF"], y=df["Rating"])

# %%
df["CocoaPercent"] = df["CocoaPercent"].apply(lambda x: np.nan if x in ['-'] else x[:-1]).astype(float)/100

# %%
sns.regplot(x=df["CocoaPercent"], y=df["Rating"])
