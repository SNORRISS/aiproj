# %%
import pandas as pd

df = pd.read_csv('D:\Downloads\FlavorsOfCocoa.csv')
df
# Out:
#      Company \n(Maker-if known)   Specific Bean Origin\nor Bar Name   REF  \
# 0                      A. Morin                         Agua Grande  1876
# 1                      A. Morin                               Kpime  1676
# 2                      A. Morin                              Atsane  1676
# 3                      A. Morin                               Akata  1680
# 4                      A. Morin                              Quilla  1704
# 5                      A. Morin                            Carenero  1315
# 6                      A. Morin                                Cuba  1315
# 7                      A. Morin                        Sur del Lago  1315
# 8                      A. Morin                      Puerto Cabello  1319
# 9                      A. Morin                             Pablino  1319
# 10                     A. Morin                              Panama  1011
# 11                     A. Morin                          Madagascar  1011
# ...

# %%
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt

multiples = sns.FacetGrid(df, col= "Cocoa\nPercent")
multiples = multiples.map(plt.hist, "Rating")

# %%
multiples = sns.FacetGrid(df, col= "Company\nLocation")
multiples = multiples.map(plt.hist, "Rating")

# %%
multiples = sns.FacetGrid(df, col= "Cocoa\nPercent")
multiples = multiples.map(plt.hist, "Company\nLocation")

# %%
multiples = sns.FacetGrid(df, col= "Bean Type")
multiples = multiples.map(plt.hist, "Rating")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bean Type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-9e57d1760386> in <module>()
# ...
